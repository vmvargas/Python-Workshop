# %% [markdown]
# ## Generating Data
#
# ### Installing matplotlib
#
# * Via pip:
#  - Open a terminal and run:
#
#     ```bash
#     python -m pip install matplotlib
#     ```
# * Via Anaconda Navigator:
#  - Open Anaconda Navigator -> Environments -> Activate desired environment -> Select Not Installed -> Search for 'matplotlib' -> Select 'matplotlib' -> Click on Apply.
#
#
# * Via Conda (recommended):
#  - Open the program "Anaconda prompt" -> execute the command: ```activate <environment_name>``` -> then: ```conda install matplotlib``` -> Proceed? y
#
# Official docs:
# https://matplotlib.org/

# %% [markdown]
# ### Plotting a Simple Line Graph
#
# First, we imported the `pyplot` module using the alias plt.
#
# `pyplot` contains a number of functions that help generate charts and plots.

# %%
import matplotlib.pyplot as plt

squares = [1, 4, 9, 16, 25]
plt.plot(input_values)
plt.show()

# %% [markdown]
# At the end of the graph the square of 4.0 is shown as 25. The data is not plotted correctly.

# %%
import matplotlib.pyplot as plt

input_values = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 25]
plt.plot(input_values, squares, linewidth=5)

# Set chart title and label axes.
plt.title("Square Numbers", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.ylabel("Square of Value", fontsize=14)

# Set size of tick labels.
plt.tick_params(axis='both', labelsize=14)

plt.show()

# %% [markdown]
# ### Plotting and Styling Individual Points with Scatter

# %%
import matplotlib.pyplot as plt

x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16, 25]

plt.scatter (x_values, y_values, s=100)

# Set chart title and label axes.
plt.title("Square Numbers", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.ylabel("Square of Value", fontsize=14)

# Set size of tick labels.
plt.tick_params(axis='both', labelsize=14)

plt.show()

# %% [markdown]
# ### Calculating Data Automatically
#
# Writting data by hand can be innefficient. Let's use a loop instead for 1,000 points.
#
# Notice how a list comprehension generates the y-values by looping through the x-values
#
# `axis()` requires 4 values: the minimum and maximum values for the x-axis and y-axis
#
# `edgecolo='none'` reomve the outlines around points

# %%
import matplotlib.pyplot as plt

x_values = list(range(1, 1001))
y_values = [x**2 for x in x_values]

plt.scatter(x_values, y_values, c=(0, 0, 0.8), edgecolor='none', s=20)

# Set chart title, and label axes.
plt.title("Square Numbers", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.ylabel("Square of Value", fontsize=14)

# Set size of tick labels.
plt.tick_params(axis='both', which='major', labelsize=14)

# Set the range for each axis.
plt.axis([0, 1100, 0, 1100000])

plt.show()

# %% [markdown]
# #### Saving your plots Automatically

# %%
import matplotlib.pyplot as plt

x_values = list(range(1, 1001))
y_values = [x**2 for x in x_values]

plt.scatter(x_values, y_values, c=(0, 0, 0.8), edgecolor='none', s=20)

# Set chart title, and label axes.
plt.title("Square Numbers", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.ylabel("Square of Value", fontsize=14)

# Set size of tick labels.
plt.tick_params(axis='both', which='major', labelsize=14)

# Set the range for each axis.
plt.axis([0, 1100, 0, 1100000])

plt.savefig('squares_plot.png', bbox_inches='tight')
